# %%
import tensorflow as tf
# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
import pathlib
import PIL
import os,random
from tensorflow import keras
from tensorflow.keras.preprocessing import image, image_dataset_from_directory
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Flatten,Conv2D,MaxPool2D,Dropout
import scipy.integrate
import scipy.special
import scipy

# %%
train_path=pathlib.Path('train_data/')
test_path=pathlib.Path('test_data/')
train_path
# Out:
# WindowsPath('train_data')

# %%
imgh, imgw = 64, 64

train_ds = ImageDataGenerator(rescale = 1./255, shear_range = 0.2, zoom_range = 0.2, horizontal_flip = True)
training_set = train_ds.flow_from_directory(train_path, target_size=(imgh, imgw), batch_size=32, class_mode='binary')

test_ds = ImageDataGenerator(rescale = 1./255)
test_set = test_ds.flow_from_directory(test_path, target_size=(imgh, imgw), batch_size=32, class_mode='binary')
# Out:
# Found 2290 images belonging to 4 classes.
# Found 975 images belonging to 4 classes.

# %%
model = keras.Sequential([
    keras.layers.Conv2D(16,(3,3),activation = "relu",input_shape =(64,64,3)),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Conv2D(32,(3,3),activation = "relu"),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Conv2D(64,(3,3),activation = "relu"),
    keras.layers.MaxPooling2D((2,2)),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation = "relu"),
    keras.layers.Dense(16, activation = "relu"),
    keras.layers.Dense(4, activation = "sigmoid"),
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 62, 62, 16)        448
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 29, 29, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 128)               295040
#
#  dense_1 (Dense)             (None, 16)                2064
#
#  dense_2 (Dense)             (None, 4)                 68
#
# =================================================================
# Total params: 320,756
# Trainable params: 320,756
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
trainHistory = model.fit(x = training_set, validation_data = test_set, epochs = 50)

plt.title('Training & Validation Accuracy')
plt.plot(trainHistory.history['accuracy'], 'green',label='Accuracy')
plt.plot(trainHistory.history['val_accuracy'], 'orange',label='Val_Accuracy')
plt.ylabel('Accurasy')
plt.xlabel('Epochs')
plt.legend(loc='upper left')
plt.grid()
plt.show()

(loss, accuracy) = model.evaluate(training_set)
print('\nTraining loss:', loss)
print('\nTraining accuracy:', accuracy)

plt.title('Training & Validation Loss')
plt.plot(trainHistory.history['loss'],'green',label='Loss')
plt.plot(trainHistory.history['val_loss'],'orange',label='Val_Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(loc='upper right')
plt.grid()
plt.show()

(loss, accuracy) = model.evaluate(test_set)
print('\nTest loss:', loss)
print('\nTest accuracy:', accuracy)

plt.plot(trainHistory.history['accuracy'],'green',label='Accuracy')
plt.plot(trainHistory.history['loss'],'red',label='Loss')
plt.title('Training Accuracy & Loss')
plt.ylabel('Accurasy and Loss')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.grid()
plt.show()

plt.plot(trainHistory.history['val_accuracy'],'green',label='Val_Accuracy')
plt.plot(trainHistory.history['val_loss'],'red',label='Val_Loss')
plt.title('Validation Accuracy & Loss')
plt.ylabel('Accurasy and Loss')
plt.xlabel('Epoch')
plt.legend(loc='lower right')
plt.grid()
plt.show()

model.save("model_flowers2.h5")
# Out:
# Epoch 1/50
# 72/72 [==============================] - 10s 132ms/step - loss: 1.2120 - accuracy: 0.4240 - val_loss: 1.1357 - val_accuracy: 0.5190
# Epoch 2/50
# 72/72 [==============================] - 7s 94ms/step - loss: 0.9725 - accuracy: 0.5690 - val_loss: 1.0534 - val_accuracy: 0.5467
# Epoch 3/50
# 72/72 [==============================] - 7s 93ms/step - loss: 0.8973 - accuracy: 0.5948 - val_loss: 0.9281 - val_accuracy: 0.5774
# Epoch 4/50
# 72/72 [==============================] - 7s 95ms/step - loss: 0.8170 - accuracy: 0.6397 - val_loss: 0.9243 - val_accuracy: 0.6021
# Epoch 5/50
# 72/72 [==============================] - 7s 96ms/step - loss: 0.7695 - accuracy: 0.6738 - val_loss: 1.0067 - val_accuracy: 0.6144
# Epoch 6/50
# 72/72 [==============================] - 7s 95ms/step - loss: 0.7328 - accuracy: 0.6926 - val_loss: 0.9553 - val_accuracy: 0.6359
# Epoch 7/50
# 72/72 [==============================] - 7s 94ms/step - loss: 0.7126 - accuracy: 0.7210 - val_loss: 0.8920 - val_accuracy: 0.6144
# Epoch 8/50
# 72/72 [==============================] - 7s 92ms/step - loss: 0.6651 - accuracy: 0.7358 - val_loss: 0.9257 - val_accuracy: 0.6410
# Epoch 9/50
# 72/72 [==============================] - 7s 94ms/step - loss: 0.6422 - accuracy: 0.7428 - val_loss: 0.8608 - val_accuracy: 0.6595
# Epoch 10/50
# 72/72 [==============================] - 7s 93ms/step - loss: 0.5991 - accuracy: 0.7677 - val_loss: 0.8983 - val_accuracy: 0.6390
# Epoch 11/50
# 72/72 [==============================] - 7s 94ms/step - loss: 0.6042 - accuracy: 0.7616 - val_loss: 0.9271 - val_accuracy: 0.6585
# Epoch 12/50
# 72/72 [==============================] - 7s 98ms/step - loss: 0.5660 - accuracy: 0.7790 - val_loss: 0.8804 - val_accuracy: 0.6667
# Epoch 13/50
# 72/72 [==============================] - 7s 94ms/step - loss: 0.5342 - accuracy: 0.7882 - val_loss: 0.9003 - val_accuracy: 0.6656
# Epoch 14/50
# 72/72 [==============================] - 7s 95ms/step - loss: 0.5395 - accuracy: 0.7908 - val_loss: 0.9089 - val_accuracy: 0.6369
# Epoch 15/50
# 72/72 [==============================] - 7s 96ms/step - loss: 0.5365 - accuracy: 0.7886 - val_loss: 1.0501 - val_accuracy: 0.6451
# Epoch 16/50
# 72/72 [==============================] - 7s 93ms/step - loss: 0.4722 - accuracy: 0.8192 - val_loss: 0.9132 - val_accuracy: 0.6574
# Epoch 17/50
# 72/72 [==============================] - 7s 94ms/step - loss: 0.5111 - accuracy: 0.7865 - val_loss: 0.9195 - val_accuracy: 0.6728
# Epoch 18/50
# 72/72 [==============================] - 7s 96ms/step - loss: 0.4663 - accuracy: 0.8183 - val_loss: 0.9490 - val_accuracy: 0.6492
# Epoch 19/50
# 72/72 [==============================] - 11s 155ms/step - loss: 0.4400 - accuracy: 0.8275 - val_loss: 0.9836 - val_accuracy: 0.6462
# Epoch 20/50
# 72/72 [==============================] - 7s 93ms/step - loss: 0.4085 - accuracy: 0.8432 - val_loss: 1.0566 - val_accuracy: 0.6431
# Epoch 21/50
# 72/72 [==============================] - 7s 93ms/step - loss: 0.3779 - accuracy: 0.8572 - val_loss: 1.2861 - val_accuracy: 0.6523
# Epoch 22/50
# 72/72 [==============================] - 7s 96ms/step - loss: 0.3927 - accuracy: 0.8463 - val_loss: 1.1021 - val_accuracy: 0.6646
# Epoch 23/50
# 72/72 [==============================] - 7s 95ms/step - loss: 0.3806 - accuracy: 0.8563 - val_loss: 1.0744 - val_accuracy: 0.6636
# Epoch 24/50
# 72/72 [==============================] - 7s 98ms/step - loss: 0.3172 - accuracy: 0.8821 - val_loss: 1.2191 - val_accuracy: 0.6421
# Epoch 25/50
# 72/72 [==============================] - 7s 94ms/step - loss: 0.3228 - accuracy: 0.8795 - val_loss: 1.1034 - val_accuracy: 0.6421
# Epoch 26/50
# 72/72 [==============================] - 7s 92ms/step - loss: 0.2982 - accuracy: 0.8882 - val_loss: 1.1518 - val_accuracy: 0.6738
# Epoch 27/50
# 72/72 [==============================] - 7s 94ms/step - loss: 0.2983 - accuracy: 0.8913 - val_loss: 1.2454 - val_accuracy: 0.6615
# Epoch 28/50
# 72/72 [==============================] - 7s 94ms/step - loss: 0.2576 - accuracy: 0.9009 - val_loss: 1.3772 - val_accuracy: 0.6349
# Epoch 29/50
# 72/72 [==============================] - 7s 96ms/step - loss: 0.2473 - accuracy: 0.9035 - val_loss: 1.2370 - val_accuracy: 0.6574
# Epoch 30/50
# 72/72 [==============================] - 7s 93ms/step - loss: 0.2384 - accuracy: 0.9148 - val_loss: 1.4733 - val_accuracy: 0.6492
# Epoch 31/50
# 72/72 [==============================] - 7s 95ms/step - loss: 0.2313 - accuracy: 0.9114 - val_loss: 1.3592 - val_accuracy: 0.6410
# Epoch 32/50
# 72/72 [==============================] - 7s 95ms/step - loss: 0.1909 - accuracy: 0.9271 - val_loss: 1.4702 - val_accuracy: 0.6646
# Epoch 33/50
# 72/72 [==============================] - 7s 96ms/step - loss: 0.1650 - accuracy: 0.9402 - val_loss: 1.8979 - val_accuracy: 0.6369
# Epoch 34/50
# 72/72 [==============================] - 7s 93ms/step - loss: 0.1852 - accuracy: 0.9275 - val_loss: 1.7112 - val_accuracy: 0.6410
# Epoch 35/50
# 72/72 [==============================] - 7s 95ms/step - loss: 0.1745 - accuracy: 0.9314 - val_loss: 1.5695 - val_accuracy: 0.6554
# Epoch 36/50
# 72/72 [==============================] - 7s 94ms/step - loss: 0.1804 - accuracy: 0.9341 - val_loss: 1.5913 - val_accuracy: 0.6349
# Epoch 37/50
# 72/72 [==============================] - 7s 94ms/step - loss: 0.1350 - accuracy: 0.9533 - val_loss: 1.8099 - val_accuracy: 0.6349
# Epoch 38/50
# 72/72 [==============================] - 7s 94ms/step - loss: 0.1258 - accuracy: 0.9550 - val_loss: 1.7399 - val_accuracy: 0.6728
# Epoch 39/50
# 72/72 [==============================] - 7s 95ms/step - loss: 0.1146 - accuracy: 0.9581 - val_loss: 1.6845 - val_accuracy: 0.6369
# Epoch 40/50
# 72/72 [==============================] - 7s 94ms/step - loss: 0.1188 - accuracy: 0.9576 - val_loss: 1.9647 - val_accuracy: 0.6092
# Epoch 41/50
# 72/72 [==============================] - 7s 99ms/step - loss: 0.1646 - accuracy: 0.9410 - val_loss: 1.8276 - val_accuracy: 0.6513
# Epoch 42/50
# 72/72 [==============================] - 7s 103ms/step - loss: 0.1373 - accuracy: 0.9489 - val_loss: 1.8246 - val_accuracy: 0.6390
# Epoch 43/50
# 72/72 [==============================] - 8s 105ms/step - loss: 0.0874 - accuracy: 0.9664 - val_loss: 1.9333 - val_accuracy: 0.6533
# Epoch 44/50
# 72/72 [==============================] - 8s 105ms/step - loss: 0.1452 - accuracy: 0.9437 - val_loss: 1.6375 - val_accuracy: 0.6708
# Epoch 45/50
# 72/72 [==============================] - 12s 160ms/step - loss: 0.0878 - accuracy: 0.9712 - val_loss: 1.9537 - val_accuracy: 0.6431
# Epoch 46/50
# 72/72 [==============================] - 7s 97ms/step - loss: 0.0745 - accuracy: 0.9773 - val_loss: 2.2490 - val_accuracy: 0.6277
# Epoch 47/50
# 72/72 [==============================] - 7s 96ms/step - loss: 0.0918 - accuracy: 0.9668 - val_loss: 2.1567 - val_accuracy: 0.6308
# Epoch 48/50
# 72/72 [==============================] - 7s 97ms/step - loss: 0.1191 - accuracy: 0.9603 - val_loss: 2.1722 - val_accuracy: 0.6492
# Epoch 49/50
# 72/72 [==============================] - 7s 101ms/step - loss: 0.0600 - accuracy: 0.9817 - val_loss: 2.0190 - val_accuracy: 0.6554
# Epoch 50/50
# 72/72 [==============================] - 7s 92ms/step - loss: 0.0904 - accuracy: 0.9694 - val_loss: 2.2202 - val_accuracy: 0.6400
# 72/72 [==============================] - 5s 73ms/step - loss: 0.0823 - accuracy: 0.9712
#
# Training loss: 0.08227494359016418
#
# Training accuracy: 0.9711790680885315
# 31/31 [==============================] - 1s 41ms/step - loss: 2.2202 - accuracy: 0.6400
#
# Test loss: 2.2202022075653076
#
# Test accuracy: 0.6399999856948853

# %%
model = keras.models.load_model("model_flowers2.h5")

# %%
test_imgs = [
    image.load_img('test_data/daisy/14354051035_1037b30421_n.jpg', target_size = (imgh, imgw)),
    image.load_img('test_data/rose/14494590921_3bb1dc7b88_n.jpg', target_size = (imgh, imgw)),
    image.load_img('test_data/tulip_test/14099204939_60e6ffa4c3_n.jpg', target_size = (imgh, imgw)),
    image.load_img('test_data/sun/12471441503_d188b5f31a_m.jpg', target_size = (imgh, imgw)),
    image.load_img('test_data/sun/14348961225_09bd803317_n.jpg', target_size = (imgh, imgw)),
    image.load_img('test_data/rose/14154164774_3b39d36778.jpg', target_size = (imgh, imgw)),
    image.load_img('test_data/rose/12338444334_72fcc2fc58_m.jpg', target_size = (imgh, imgw)),
    image.load_img('test_data/tulip_test/14254329062_140c0f4f4f_n.jpg', target_size = (imgh, imgw)),
    
    image.load_img('test_data/daisy/18023717391_e2c9089e10.jpg', target_size = (imgh, imgw)),
    image.load_img('test_data/sun/14925398441_107f3e0304_n.jpg', target_size = (imgh, imgw)),
    image.load_img('test_data/tulip_test/15049902081_dd85361f8c_m.jpg', target_size = (imgh, imgw)),
    image.load_img('test_data/tulip_test/16717320956_d4b00807f2.jpg', target_size = (imgh, imgw)),
    image.load_img('test_data/rose/15255964274_cf2ecdf702.jpg', target_size = (imgh, imgw)),
    image.load_img('test_data/daisy/34693373736_9ce6d9e1c3_n.jpg', target_size = (imgh, imgw)),
    
    image.load_img('test_data/tulip_test/14097366955_84ef6369f2.jpg', target_size = (imgh, imgw)),    
]
#predictions = model.predict(test_imgs)
i=0 
fig, ax = plt.subplots(1,15)
for _img in test_imgs:
    test_img = _img
    img = image.img_to_array(test_img)
    img = np.expand_dims(img, axis = 0)
    r = model.predict(img)
    #test_set.class_indices
    if r[0][0] == 1:
        test1 = 'd'
    elif r[0][1] == 1:
        test1 = 'r'
    elif r[0][2] == 1: 
        test1 = 's'
    else:
        test1 = 't'
    
    ax[i].axis('off')
    ax[i].set_title(test1)
    ax[i].imshow(_img)
    i += 1
    
plt.show()
# Out:
# 1/1 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 47ms/step
